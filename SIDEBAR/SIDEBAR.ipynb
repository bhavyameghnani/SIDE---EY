# %%
from flask import Flask, request
app = Flask(__name__)

# %%
# !pip install azure-core
# !pip install azure-ai-formrecognizer==3.2.0b3
# !pip install pandas

import pandas as pd

from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

endpoint = "https://ey.cognitiveservices.azure.com/"
key = "d9766f2054af470682a4e3d8963a0d31"


from io import BytesIO

@app.route('/sideBar', methods = ['GET', 'POST'])
def sideBar():
    if request.method == 'POST':
        print('Inside function 2')
        print(request.data)
        file = request.data['filename']
        filename = file.filename
        print(file)
        with open(file, 'rb') as fd:
            document = fd.read()

        document_analysis_client = DocumentAnalysisClient(
            endpoint=endpoint, credential=AzureKeyCredential(key)
        )

        poller = document_analysis_client.begin_analyze_document("prebuilt-layout", document)
        result = poller.result()
        df = pd.DataFrame()
        # df = result.tables


        for idx, style in enumerate(result.styles):
            print(
                "Document contains {} content".format(
                 "handwritten" if style.is_handwritten else "no handwritten"
                )
            )

        for page in result.pages:
            for line_idx, line in enumerate(page.lines):
                print(
                 "...Line # {} has text content '{}'".format(
                line_idx,
                line.content.encode("utf-8")
                )
            )

            for selection_mark in page.selection_marks:
                print(
                 "...Selection mark is '{}' and has a confidence of {}".format(
                 selection_mark.state,
                 selection_mark.confidence
                 )
            )


        df = table.cells
        last = df[-1]
        r, c = last.row_index+1, last.column_index+1
        print(r,c)
        csv = [[None for i in range(c)] for j in range(r)]
        print(csv)
        import numpy as np

        for table_idx, table in enumerate(result.tables):
            print(
                "Table # {} has {} rows and {} columns".format(
                table_idx, table.row_count, table.column_count
                )
            )
            df = []  
            #print(table.cells)
            for cell in table.cells:
                print(
                    "...Cell[{}][{}] has content '{}'".format(
                    cell.row_index,
                    cell.column_index,
                    cell.content.encode("utf-8"),
                  )

                )
        #         csv[cell.row_index][cell.column_index] = str(cell.content.encode("utf-8"))
        #         print(csv)

        print("----------------------------------------")

        print(csv)
        import pandas as pd
        df = pd.DataFrame(csv)
        df.to_csv("final.csv",index=False, header=False)

        response("Done")

# %%
app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2022-05-18 18:43:09,840] ERROR in app: Exception on /sideBar [POST]
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/anaconda3/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-20-842bebc304a8>", line 21, in sideBar
#     file = request.data['filename']
# TypeError: byte indices must be integers or slices, not str
# 127.0.0.1 - - [18/May/2022 18:43:09] "POST /sideBar HTTP/1.1" 500 -
# Inside function 2
# b''

# %%
dff = pd.read_csv("final.csv")

# %%
import pandas as pd

from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

endpoint = "https://ey.cognitiveservices.azure.com/"
key = "d9766f2054af470682a4e3d8963a0d31"


from io import BytesIO

file='sample1.png'

    
with open(file, 'rb') as fd:
    document = fd.read()

document_analysis_client = DocumentAnalysisClient(
    endpoint=endpoint, credential=AzureKeyCredential(key)
)

poller = document_analysis_client.begin_analyze_document("prebuilt-layout", document)
result = poller.result()
df = pd.DataFrame()
# df = result.tables


for idx, style in enumerate(result.styles):
    print(
        "Document contains {} content".format(
         "handwritten" if style.is_handwritten else "no handwritten"
        )
    )

for page in result.pages:
    for line_idx, line in enumerate(page.lines):
        print(
         "...Line # {} has text content '{}'".format(
        line_idx,
        line.content.encode("utf-8")
        )
    )

    for selection_mark in page.selection_marks:
        print(
         "...Selection mark is '{}' and has a confidence of {}".format(
         selection_mark.state,
         selection_mark.confidence
         )
    )


df = table.cells
last = df[-1]
r, c = last.row_index+1, last.column_index+1
print(r,c)
csv = [[None for i in range(c)] for j in range(r)]
print(csv)
import numpy as np

for table_idx, table in enumerate(result.tables):
    print(
        "Table # {} has {} rows and {} columns".format(
        table_idx, table.row_count, table.column_count
        )
    )
    df = []  
    #print(table.cells)
    for cell in table.cells:
        print(
            "...Cell[{}][{}] has content '{}'".format(
            cell.row_index,
            cell.column_index,
            cell.content.encode("utf-8"),
          )

        )
        csv[cell.row_index][cell.column_index] = str(cell.content.encode("utf-8"))
#         print(csv)

print("----------------------------------------")

print(csv)
import pandas as pd
df = pd.DataFrame(csv)
df.to_csv("final.csv",index=False, header=False)

response("Done")
# Out:
# ...Line # 0 has text content 'b'By region (a)''
# ...Line # 1 has text content 'b'Developed markets''
# ...Line # 2 has text content 'b'Sales''
# ...Line # 3 has text content 'b"$'m"'
# ...Line # 4 has text content 'b'vs Plan''
# ...Line # 5 has text content 'b'%''
# ...Line # 6 has text content 'b'VS PY''
# ...Line # 7 has text content 'b'%''
# ...Line # 8 has text content 'b'Region 1''
# ...Line # 9 has text content 'b'$''
# ...Line # 10 has text content 'b'518''
# ...Line # 11 has text content 'b'8.8%''
# ...Line # 12 has text content 'b'34.3%''
# ...Line # 13 has text content 'b'Region 2''
# ...Line # 14 has text content 'b'2,791''
# ...Line # 15 has text content 'b'9.6%''
# ...Line # 16 has text content 'b'26.9%''
# ...Line # 17 has text content 'b'Region 3''
# ...Line # 18 has text content 'b'233''
# ...Line # 19 has text content 'b'12.4%''
# ...Line # 20 has text content 'b'26.1%''
# ...Line # 21 has text content 'b'Region 4''
# ...Line # 22 has text content 'b'675''
# ...Line # 23 has text content 'b'2.8%''
# ...Line # 24 has text content 'b'18.1%''
# ...Line # 25 has text content 'b'Region 5''
# ...Line # 26 has text content 'b'726''
# ...Line # 27 has text content 'b'4.1%''
# ...Line # 28 has text content 'b'17.0%''
# ...Line # 29 has text content 'b'Region 6''
# ...Line # 30 has text content 'b'197''
# ...Line # 31 has text content 'b'6.9%''
# ...Line # 32 has text content 'b'16.8%''
# ...Line # 33 has text content 'b'Region 7''
# ...Line # 34 has text content 'b'1,557''
# ...Line # 35 has text content 'b'2.0%''
# ...Line # 36 has text content 'b'16.7%''
# ...Line # 37 has text content 'b'Region 8''
# ...Line # 38 has text content 'b'1,510''
# ...Line # 39 has text content 'b'5.4%''
# ...Line # 40 has text content 'b'14.1%''
# ...Line # 41 has text content 'b'Region 9''
# ...Line # 42 has text content 'b'723''
# ...Line # 43 has text content 'b'5.6%''
# ...Line # 44 has text content 'b'12.9%''
# ...Line # 45 has text content 'b'Region 10''
# ...Line # 46 has text content 'b'1,519''
# ...Line # 47 has text content 'b'8.0%''
# ...Line # 48 has text content 'b'12.8%''
# ...Line # 49 has text content 'b'Region 11''
# ...Line # 50 has text content 'b'688''
# ...Line # 51 has text content 'b'(3.8%)''
# ...Line # 52 has text content 'b'12.5%''
# ...Line # 53 has text content 'b'Region 12''
# ...Line # 54 has text content 'b'1,433''
# ...Line # 55 has text content 'b'4.3%''
# ...Line # 56 has text content 'b'9.7%''
# ...Line # 57 has text content 'b'Region 13''
# ...Line # 58 has text content 'b'3,155''
# ...Line # 59 has text content 'b'1.1%''
# ...Line # 60 has text content 'b'8.0%''
# ...Line # 61 has text content 'b'Subtotal Developed markets''
# ...Line # 62 has text content 'b'$ 15,212''
# ...Line # 63 has text content 'b'4.5%''
# ...Line # 64 has text content 'b'14.9%''
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-57350dad1f6d> in <module>
#      51
#      52
# ---> 53 df = table.cells
#      54 last = df[-1]
#      55 r, c = last.row_index+1, last.column_index+1
#
# NameError: name 'table' is not defined

# %%
import pandas as pd
from io import BytesIO

file='test3.pdf'
    
with open(file, 'rb') as fd:
    document = fd.read()
    
from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient

endpoint = "https://ey.cognitiveservices.azure.com/"
key = "d9766f2054af470682a4e3d8963a0d31"

document_analysis_client = DocumentAnalysisClient(
    endpoint=endpoint, credential=AzureKeyCredential(key)
)
    
poller = document_analysis_client.begin_analyze_document("prebuilt-layout", document)
result = poller.result()

for idx, style in enumerate(result.styles):
    print(
        "Document contains {} content".format(
         "handwritten" if style.is_handwritten else "no handwritten"
        )
    )

for page in result.pages:
    for line_idx, line in enumerate(page.lines):
        print(
         "...Line # {} has text content '{}'".format(
        line_idx,
        line.content.encode("utf-8")
        )
    )

    for selection_mark in page.selection_marks:
        print(
         "...Selection mark is '{}' and has a confidence of {}".format(
         selection_mark.state,
         selection_mark.confidence
         )
    )

df = table.cells
last = df[-1]
r, c = last.row_index+1, last.column_index+1
print(r,c)
csv = [[None for i in range(c)] for j in range(r)]
        
for table_idx, table in enumerate(result.tables):
    print(
        "Table # {} has {} rows and {} columns".format(
        table_idx, table.row_count, table.column_count
        )
    )
        
    for cell in table.cells:
        print(
            "...Cell[{}][{}] has content '{}'".format(
            cell.row_index,
            cell.column_index,
            cell.content.encode("utf-8"),
            )
        )
#         csv[cell.row_index][cell.column_index] = str(cell.content.encode("utf-8"))

print("----------------------------------------")




import pandas as pd
df = pd.DataFrame(csv)
df.to_csv("final.csv",index=False, header=False)
# Out:
# ...Line # 0 has text content 'b'ID''
# ...Line # 1 has text content 'b'Name''
# ...Line # 2 has text content 'b'1 Automation''
# ...Line # 3 has text content 'b'2 HR''
# ...Line # 4 has text content 'b'3 Finance''
# ...Line # 5 has text content 'b'4 RMS''
# ...Line # 6 has text content 'b'5 Marketing''
# ...Line # 7 has text content 'b'ID''
# ...Line # 8 has text content 'b'Name''
# ...Line # 9 has text content 'b'Dept ID''
# ...Line # 10 has text content 'b'Location''
# ...Line # 11 has text content 'b'10005 Ram''
# ...Line # 12 has text content 'b'1 IN01''
# ...Line # 13 has text content 'b'10006 Sham''
# ...Line # 14 has text content 'b'3 IN01''
# ...Line # 15 has text content 'b'10007 Vicky''
# ...Line # 16 has text content 'b'2 UK02''
# ...Line # 17 has text content 'b'10008 Akshay''
# ...Line # 18 has text content 'b'4 IN02''
# ...Line # 19 has text content 'b'10009 Kaushal''
# ...Line # 20 has text content 'b'5 UK02''
# ...Line # 21 has text content 'b'Id''
# ...Line # 22 has text content 'b'Name''
# ...Line # 23 has text content 'b'IN01''
# ...Line # 24 has text content 'b'Delhi''
# ...Line # 25 has text content 'b'UK02 Manchester''
# ...Line # 26 has text content 'b'IN02''
# ...Line # 27 has text content 'b'Bangalore''
# 9 12
# Table # 0 has 6 rows and 4 columns
# ...Cell[0][0] has content 'b'ID''
# ...Cell[0][1] has content 'b'Name''
# ...Cell[0][2] has content 'b'Dept ID''
# ...Cell[0][3] has content 'b'Location''
# ...Cell[1][0] has content 'b'10005''
# ...Cell[1][1] has content 'b'Ram''
# ...Cell[1][2] has content 'b'1''
# ...Cell[1][3] has content 'b'IN01''
# ...Cell[2][0] has content 'b'10006''
# ...Cell[2][1] has content 'b'Sham''
# ...Cell[2][2] has content 'b'3''
# ...Cell[2][3] has content 'b'IN01''
# ...Cell[3][0] has content 'b'10007''
# ...Cell[3][1] has content 'b'Vicky''
# ...Cell[3][2] has content 'b'2''
# ...Cell[3][3] has content 'b'UK02''
# ...Cell[4][0] has content 'b'10008''
# ...Cell[4][1] has content 'b'Akshay''
# ...Cell[4][2] has content 'b'4''
# ...Cell[4][3] has content 'b'IN02''
# ...Cell[5][0] has content 'b'10009''
# ...Cell[5][1] has content 'b'Kaushal''
# ...Cell[5][2] has content 'b'5''
# ...Cell[5][3] has content 'b'UK02''
# Table # 1 has 4 rows and 2 columns
# ...Cell[0][0] has content 'b'Id''
# ...Cell[0][1] has content 'b'Name''
# ...Cell[1][0] has content 'b'IN01''
# ...Cell[1][1] has content 'b'Delhi''
# ...Cell[2][0] has content 'b'UK02''
# ...Cell[2][1] has content 'b'Manchester''
# ...Cell[3][0] has content 'b'IN02''
# ...Cell[3][1] has content 'b'Bangalore''
# Table # 2 has 6 rows and 2 columns
# ...Cell[0][0] has content 'b'ID''
# ...Cell[0][1] has content 'b'Name''
# ...Cell[1][0] has content 'b'1''
# ...Cell[1][1] has content 'b'Automation''
# ...Cell[2][0] has content 'b'2''
# ...Cell[2][1] has content 'b'HR''
# ...Cell[3][0] has content 'b'3''
# ...Cell[3][1] has content 'b'Finance''
# ...Cell[4][0] has content 'b'4''
# ...Cell[4][1] has content 'b'RMS''
# ...Cell[5][0] has content 'b'5''
# ...Cell[5][1] has content 'b'Marketing''
# ----------------------------------------

# %%
df.head()
# Out:
#       0     1
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None
